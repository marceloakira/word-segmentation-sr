# %% [markdown]
# # Análise dos dados extraídos

# %%
import pandas as pd
import bibtexparser

# %%
df = pd.read_csv('selected-merged.csv')
# print(df['identifier']+' '+df['title'])
print(df['identifier'])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-e6dfb5b60b99> in <module>
# ----> 1 df = pd.read_csv('selected-merged.csv')
#       2 # print(df['identifier']+' '+df['title'])
#       3 print(df['identifier'])
#
# ...

# %%
#with open('citations/selected1and2-2019-10-07/selected-merged.bib') as bibtex_file:
 #   bib_db = bibtexparser.load(bibtex_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/bibtexparser/bibdatabase.py in expand_string(self, name)
#     113             return BibDataStringExpression.expand_if_expression(
# --> 114                 self.strings[name])
#     115         except KeyError:
#
# KeyError: 'jul'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedString                           Traceback (most recent call last)
# <ipython-input-5-cb425111d6c3> in <module>
#       1 with open('citations/selected1and2-2019-10-07/selected-merged.bib') as bibtex_file:
# ----> 2     bib_db = bibtexparser.load(bibtex_file)
#
# /usr/local/lib/python3.6/dist-packages/bibtexparser/__init__.py in load(bibtex_file, parser)
#      69     if parser is None:
#      70         parser = bparser.BibTexParser()
# ...
